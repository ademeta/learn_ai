# %%
import os, sys
from dotenv import load_dotenv
from pathlib import Path
from docx import Document

from openai import OpenAI

dotenv_path = os.path.join(os.getcwd(), '.env') # not necessary
load_dotenv(dotenv_path)
# Out:
# True

# %%
OPEN_AI_KEY = os.environ.get('OPENAI_API_KEY')
if not OPEN_AI_KEY:
    print('openai key empty!')

# %%
message="Hi there!, what do you think of 2026 so far?"

messages = [
    {"role": "user","content": message}
]
messages
# Out:
# [{'role': 'user', 'content': 'Hi there!, what do you think of 2026 so far?'}]

# %%
openai = OpenAI(api_key=OPEN_AI_KEY)

# %%
response = openai.chat.completions.create(messages=messages, model="gpt-5-nano")
print(response.choices[0].message.content)
# Out:
# Hi! I don’t have real-time updates beyond mid-2024, but we can chat about 2026 so far in terms of trends and what people are watching.
#
# Here are some broad themes that many folks are following in 2026 (based on ongoing trajectories):
#
# - AI and automation: more AI copilots in work and everyday tools, faster code and content generation, plus ongoing talks about safety, ethics, and governance. Expect better integration into workflows, with rising emphasis on responsible AI.
#
# - Climate, energy, and policy: accelerated deployment of renewables, energy storage advances, and climate resilience planning. Policy debates around carbon regulation, incentives for clean tech, and adaptation to extreme weather.
#
# - Economy and geopolitics: shifts in global supply chains, ongoing tech competition, and discussions about data governance and digital currencies. Inflation dynamics and interest-rate trends continue to be watched, with a focus on resilience and diversification.
#
# - Space and science: continued launches and private sector activity, more satellite networks, and advancing space science missions that could impact communications, navigation, and exploration.
#
# - Work and culture: hybrid/remote work evolution, digital wellbeing tools, and privacy/safety considerations in a more tech-enabled daily life.
#
# If you tell me what you’re most curious about (tech, world news, climate, culture, personal productivity, etc.), I can tailor a quick briefing or explain any concepts you want. Or I can draft a short 3–5 minute read that sums up what’s mattered in early 2026 and what to watch next.

# %% [markdown]
# ### Prompt Types
# - system
# - user

# %%
user_message = "what is 2+2?"

messages = [
    {"role": "system", "content": "You're a helpful assistant"},
    {"role": "user", "content": user_message}
]

# %%
response = openai.chat.completions.create(messages=messages, model="gpt-5-nano")
print(response.choices[0].message.content)
# Out:
# Two plus two equals four.

# %% [markdown]
# ### Using OpenAI for document summarization

# %%
def read_word_file(file_path):
    doc = Document(file_path)
    text = "\n".join([p.text for p in doc.paragraphs])
    return text

# %%
def summarize_docx(file_path):
    content = read_word_file(file_path)

    system_prompt = """
    You're a helpful summarizing assistant. 
    Summarize text with high quality details. 
    Do not give unnecessary information.
    """

    user_prompt = """
    Give a brief summary of this document. 
    Highlighting important information for quick action.
    """

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt + content}
    ]

    response = openai.chat.completions.create(messages=messages, model="gpt-4.1-mini")
    return print(response.choices[0].message.content)

# %%
summarize_docx("docx/P2P_Lending_The_Lending_Club.docx")
# Out:
# Summary of Peer to Peer Lending (The Lending Club) Document for Quick Action:
#
# **Product Overview:**
# - Platform: Web and Mobile app using data analysis, machine learning, AI, and cloud hosting.
# - Data sources: Application data, open banking, credit bureau.
# - Marketing: SEO, broadcast, digital ads, branding.
# - Product management includes potential extended products like foreign exchange.
#
# **Operations:**
# - Customer Underwriting: Sets policies (e.g., exclude students, retirees; age 18-60; focus on employed), uses ML scores for risk, affordability checks, verifies references and KYC documents.
# - Customer Management: Monitors loan portfolio health, tracks repayments/missed payments, creates quarterly forecasts.
# - Collections/Debt Recovery: Manages overdue loans via staged contact (SMS, email, phone calls), establishes repayment plans or payment holidays, escalates to debt collectors if necessary.
# - Impairment: Sets aside reserves for missed payments (may be optional due to investor-managed portfolios).
# - Customer Service: Handles queries, eligibility, benefits info, and directs to website FAQs.
#
# **Investor Experience:**
# - KYC: Investors provide passport/NIN/BVN, source of funds, employment, address, affiliations.
# - Journey: Investors get a username, access borrowers ranked by risk (credit score, history, interest rate, term), fund borrowers directly or via platform wallet.
# - Platform takes a percentage of returns only when investors receive payments.
# - Investors earn badges based on deals completed and adhere to transaction limits aligned with AML regulations.
#
# **Borrower Experience:**
# - KYC: Similar to investors, with document and affiliation verification.
# - Journey: Submit detailed application with references; underwriters vet applications.
# - Borrowers get ranked dynamically by risk and repayment performance.
# - Borrowers earn performance points convertible to cash/trade, influencing rank and badges (bronze to premium). Top borrowers get loan priority and access to multiple loans.
# - Rankings displayed publicly with indicators for movement (up/down/no change).
# - Customers rejoin pool only if they seek new loans post repayment.
#
# **Key Action Points:**
# - Enforce underwriting policies strictly.
# - Utilize ML risk scoring and affordability checks effectively.
# - Maintain active portfolio monitoring and collections strategies.
# - Implement dynamic borrower and investor ranking systems with incentives.
# - Ensure strong KYC and reference verification for both investors and borrowers.
# - Monitor and adjust marketing channels based on performance.
# - Adhere to regulatory requirements including AML and impairment practices.
# - Foster transparency and motivation via public rankings and reward points system.
